# %%
import sampleData

# %%
bn = sampleData.smallBn()

# %%
import skimage.color

# %%
import skimage

# %%
hsv = skimage.img_as_ubyte(skimage.color.rgb2hsv(bn))
# Out:
# /Users/Spencer/anaconda/envs/python3_5/lib/python3.5/site-packages/skimage/util/dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))

# %%
import numpy as np

# %%
hueChannel = hsv[:, :, 0]

# %%
hueChannel
# Out:
# array([[243, 243, 243, ..., 244, 245, 245],
#        [243, 243, 243, ..., 244, 244, 245],
#        [243, 243, 243, ..., 244, 244, 244],
#        ...,
#        [239, 239, 239, ..., 239, 239, 239],
#        [237, 237, 237, ..., 239, 239, 239],
#        [232, 234, 235, ..., 239, 239, 239]], dtype=uint8)

# %%
hueHisto, _ = np.histogram(hueChannel, bins=np.arange(0,256))

# %%
hueHisto
# Out:
# array([   991,    753,    882,    867,    741,    822,    783,   1002,
#           771,    861,    704,   1046,    973,    996,   1128,   1272,
#          1433,   1466,   2951,  12715,  17226,   2317,   2644,   6136,
#          3921,   2081,   1862,   1671,   1750,   1798,   1484,   1895,
#          2107,   1875,   1750,   1670,   1308,   1320,   1141,   1373,
#          1462,   1459,   1814,    706,    989,   1257,   1104,   1179,
#          1047,   1640,   1340,   1185,   1580,   1250,   1380,   1459,
#          1135,   1286,   1087,   1098,   1129,   1130,    989,   1145,
#          1044,   1324,   1633,   1692,   1779,   3172,   5073,   5951,
#          4657,   2914,   1385,   1326,   1322,   1369,   2005,   1898,
#          1545,   1185,   1430,   1778,   2213,   2699,   3257,   5233,
#          9264,  17123,  16468,   8305,   3695,    816,    805,    534,
#           507,    698,    806,    640,    699,    738,    700,    801,
# ...

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(hueHisto)

# %%
plt.imshow(hsv)

# %%
def plotHistogram(image, channel):
    channelImage = image[:, :, channel]
    histo, _ = np.histogram(channelImage, bins=np.arange(256))
    plt.plot(histo)

# %%
plotHistogram(hsv, 0)

# %%
plotHistogram(hsv, 1)

# %%
plotHistogram(hsv, 2)

# %%
plotHistogram(bn, 0); plotHistogram(bn, 1); plotHistogram(bn, 2)

# %%
plt.imshow(hsv[:, :, 0]); plt.colorbar()

# %%
from importsForTesting import *

# %%
hsvsgr = skimage.img_as_ubyte(skimage.color.rgb2hsv(sgr))
# Out:
# /Users/Spencer/anaconda/envs/python3_5/lib/python3.5/site-packages/skimage/util/dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))

# %%
plt.imshow(hsvsgr[:, :, 0]); plt.colorbar()

# %%
hsvgr = skimage.img_as_ubyte(skimage.color.rgb2hsv(gr))
# Out:
# /Users/Spencer/anaconda/envs/python3_5/lib/python3.5/site-packages/skimage/util/dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))

# %%
plt.imshow(hsvgr[:, :, 0]); plt.colorbar()

# %%
plt.imshow(hsvgr[:, :, 0] < 200)

# %%
plt.imshow(hsv[:, :, 0]); plt.colorbar()

# %%
plt.imshow(sbn)

# %%
plt.imshow(hsv[:, :, 1]); plt.colorbar()

# %%
plt.imshow(hsv[:, :, 2]); plt.colorbar()
