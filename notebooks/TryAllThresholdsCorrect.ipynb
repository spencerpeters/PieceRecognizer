# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append("../src")
import sampleData

# %%
import spencerUtilities

# %%
mono = sampleData.monolayer()

# %%
from skimage.color import rgb2hsv

# %%
greyMono = rgb2hsv(mono)[:, :, 0]

# %%
from skimage.filters import try_all_threshold

# %%
try_all_threshold(greyMono, figsize=(10, 20))
# Out:
# skimage.filters.thresholding.threshold_isodata
# skimage.filters.thresholding.threshold_minimum
# skimage.filters.thresholding.threshold_otsu
# skimage.filters.thresholding.threshold_yen
# skimage.filters.thresholding.threshold_li
# skimage.filters.thresholding.threshold_triangle
# skimage.filters.thresholding.threshold_mean
# (<matplotlib.figure.Figure at 0x115850668>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x115856630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x108617240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10865e278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1303318d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x130377eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x15e47b550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x15e4bc668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x15e4e92e8>], dtype=object))

# %%
from skimage.filters import threshold_local

# %%
plt.imshow(threshold_local(greyMono, 21))

# %%
tl = threshold_local(greyMono, 4095)

# %%
result = greyMono > tl

# %%
plt.imshow(mono)

# %%
plt.imshow(result, cmap='gray')

# %% [markdown]
# closest to identifying monolayer i've seen

# %% [markdown]
# what is this markdown

# %% [markdown]
# what is this, markdown??
# ===

# %% [raw]
# plt.imshow(mono)

# %% [markdown]
# **some text**
#
#     some code
#     for i in range
#
# 1. bla
# 2. foo
