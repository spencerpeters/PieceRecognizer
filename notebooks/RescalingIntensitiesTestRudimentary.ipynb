# %%
import sampleData

# %%
from spencerUtilities import *

# %%
bn = sampleData.smallBn()

# %%
greyBn = skimage.color.rgb2gray(bn)

# %%
thresh = skimage.filters.threshold_otsu(greyBn)

# %%
thresh
# Out:
# 0.57137862208946077

# %%
# %matplotlib inline

# %%
plotHistogram(greyBn)

# %%
gn = sampleData.smallGraphene()

# %%
greyGn = skimage.color.rgb2gray(gn)

# %%
plotHistogram(greyGn)

# %%
plt.imshow(greyGn)

# %%
mono = sampleData.monolayer()

# %%
grayMono = skimage.color.rgb2gray(mono)

# %%
plt.imshow(grayMono)

# %%
plotHistogram(grayMono)

# %%
import importlib

# %%
import spencerUtilities

# %%
importlib.reload(spencerUtilities)
# Out:
# <module 'spencerUtilities' from '/Users/Spencer/PycharmProjects/PieceRecognizer/spencerUtilities.py'>

# %%
plotHistogram(grayMono, log=True)
# Out:
# /Users/Spencer/PycharmProjects/PieceRecognizer/spencerUtilities.py:19: RuntimeWarning: divide by zero encountered in log
#   histo = np.log(histo)

# %%
from skimage.filters.rank import gradient

# %%
from skimage.morphology import disk

# %%
grad = gradient(grayMono, disk(5))
# Out:
# /Users/Spencer/anaconda/lib/python3.4/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))

# %%
plt.imshow(grad)

# %%
spencerUtilities.plotHistogram(grad)

# %%
from skimage.exposure import *

# %%
equal = equalize_hist(grad)

# %%
plt.imshow(equal)

# %%
defaultRescale = rescale_intensity(grad)

# %%
plt.imshow(defaultRescale)

# %%
selectiveRescale = rescale_intensity(grad, in_range=(0, 50))

# %%
plt.imshow(selectiveRescale)

# %%
spencerUtilities.plotHistogram(selectiveRescale)

# %%
import skimage.filters.edges

# %%
skimage.filters.edges.sobel_v
# Out:
# <function skimage.filters.edges.sobel_v>

# %%
import skimage.filters
