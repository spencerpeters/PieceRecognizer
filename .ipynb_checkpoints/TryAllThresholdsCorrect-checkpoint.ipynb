# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
import sampleData

# %%
import spencerUtilities

# %%
mono = sampleData.monolayer()

# %%
greyMono = sampleData.rgb2gray(mono)

# %%
from skimage.filters import try_all_threshold

# %%
try_all_threshold(greyMono, figsize=(10, 20))
# Out:
# skimage.filters.thresholding.threshold_triangle
# skimage.filters.thresholding.threshold_li
# skimage.filters.thresholding.threshold_minimum
# skimage.filters.thresholding.threshold_isodata
# skimage.filters.thresholding.threshold_yen
# skimage.filters.thresholding.threshold_otsu
# skimage.filters.thresholding.threshold_mean
# (<matplotlib.figure.Figure at 0x11d220d68>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x11d218860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12db11048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12db1be48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x134a01e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x134a4ae10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x134a9fba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x134ae98d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x134b44f28>], dtype=object))

# %%
from skimage.filters import threshold_local

# %%
plt.imshow(threshold_local(greyMono, 21))

# %%
tl = threshold_local(greyMono, 4095)

# %%
result = greyMono > tl

# %%
plt.imshow(result, cmap='gray')
